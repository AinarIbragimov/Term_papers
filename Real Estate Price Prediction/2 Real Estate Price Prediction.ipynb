# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

pd.options.display.max_columns = 100
# %matplotlib inline

# %%
#считаем исходные данные
data = pd.read_csv('input.train.csv')

# %%
train, valid = train_test_split(data, test_size=0.3, random_state=42)

# %%
train.head()
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 9069  14604          23    1.0   41.681380   22.796166            8.0     14
# 2603   5621          23    3.0  163.495333  161.504222           12.0      5
# 7738    235          87    1.0   39.710131   19.538663            8.0      4
# 1579  16258          48    3.0   96.056784   98.152802            1.0     15
# 5058  10773          77    3.0   79.195825   44.421062           10.0     16
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 9069        17.0       2015   0.075779         B         B         6
# 2603         3.0       1977   0.014073         B         B         2
# 7738        17.0       1986   0.100456         B         B        43
# 1579         1.0       2017   0.041125         B         B        46
# 5058        17.0       1984   0.298205         B         B        16
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 9069      1437         3           NaN            0        2       B
# 2603       475         0           NaN            0        0       B
# 7738      7227         0           NaN            1        6       A
# 1579      9515         5           NaN            1       10       B
# 5058      4048         3           NaN            1        3       B
#
#               Price
# 9069   88504.384965
# 2603  207007.956663
# 7738  182126.280899
# 1579  524365.550705
# 5058  322048.433990

# %%
train.shape
# Out:
# (7000, 20)

# %%
valid.head()
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 6252   3702          21    2.0  48.812195   34.679779            5.0      5
# 4684  12848          61    3.0  81.103039   49.310278            8.0      4
# 1731   2239           6    3.0  82.882978    3.977650            1.0      8
# 4742  15611          23    1.0  33.863324   29.993297            0.0      5
# 4521   5634          52    1.0  43.095135         NaN            1.0     10
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 6252         5.0       1963   0.034331         B         B        25
# 4684         4.0       1960   0.298205         B         B        16
# 1731        17.0       1977   0.243205         B         B         5
# 4742         4.0       1977   0.034656         B         B         0
# 4521        17.0       1977   0.371149         B         B        34
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 6252      5487         3           NaN            0        4       B
# 4684      4048         3           NaN            1        3       B
# 1731      1564         0         540.0            0        0       B
# 4742       168         0           NaN            0        0       B
# 4521      7065         1         750.0            2        5       B
#
#               Price
# 6252  181530.459031
# 4684  260456.004692
# 1731  219945.304640
# 4742   66883.280318
# 4521  114086.065201

# %%
valid.shape
# Out:
# (3000, 20)

# %% [markdown]
# # Анализ и предобработка исходных данных

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7000 entries, 9069 to 7270
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             7000 non-null   int64
#  1   DistrictId     7000 non-null   int64
#  2   Rooms          7000 non-null   float64
#  3   Square         7000 non-null   float64
#  4   LifeSquare     5514 non-null   float64
#  5   KitchenSquare  7000 non-null   float64
#  6   Floor          7000 non-null   int64
#  7   HouseFloor     7000 non-null   float64
#  8   HouseYear      7000 non-null   int64
#  9   Ecology_1      7000 non-null   float64
#  10  Ecology_2      7000 non-null   object
#  11  Ecology_3      7000 non-null   object
#  12  Social_1       7000 non-null   int64
#  13  Social_2       7000 non-null   int64
#  14  Social_3       7000 non-null   int64
#  15  Healthcare_1   3642 non-null   float64
#  16  Helthcare_2    7000 non-null   int64
#  17  Shops_1        7000 non-null   int64
#  18  Shops_2        7000 non-null   object
#  19  Price          7000 non-null   float64
# dtypes: float64(8), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
#Алгоритм обработки (подготовки) данных в общем виде:
#В поле HouseYear найдем и исправим аномальные данные
#Поле Healthcare_1 использовать в нашей модели не будем
#Поля Ecology_2, Ecology_3 и Shops_2 переведем в категориальные
#Добавим столбец mean_price со средней ценой

# %% [markdown]
# ## Поле HouseYear

# %%
#Визуализируем данные о HouseYear
sns.boxplot(train['HouseYear'], orient='v')
# Out:
# <AxesSubplot:xlabel='HouseYear'>

# %%
#Убедиться визуально, что в HouseYear присутствуют аномальные значения
plt.plot(train['HouseYear'])

# %%
#Найдем средний год постройки дома
mean_year = np.round(train.loc[(train['HouseYear'] <= 2020) & (train['HouseYear'] > 1900), 'HouseYear'].mean())
mean_year
# Out:
# 1985.0

# %%
#Очистим данные от аномалий
def clean_year(df, mean_year=mean_year):
    df.loc[(df['HouseYear'] > 2020) | (df['HouseYear'] < 1900), 'HouseYear'] = mean_year
    return df

# %%
train=clean_year(train)
train.head()
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 9069  14604          23    1.0   41.681380   22.796166            8.0     14
# 2603   5621          23    3.0  163.495333  161.504222           12.0      5
# 7738    235          87    1.0   39.710131   19.538663            8.0      4
# 1579  16258          48    3.0   96.056784   98.152802            1.0     15
# 5058  10773          77    3.0   79.195825   44.421062           10.0     16
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 9069        17.0     2015.0   0.075779         B         B         6
# 2603         3.0     1977.0   0.014073         B         B         2
# 7738        17.0     1986.0   0.100456         B         B        43
# 1579         1.0     2017.0   0.041125         B         B        46
# 5058        17.0     1984.0   0.298205         B         B        16
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 9069      1437         3           NaN            0        2       B
# 2603       475         0           NaN            0        0       B
# 7738      7227         0           NaN            1        6       A
# 1579      9515         5           NaN            1       10       B
# 5058      4048         3           NaN            1        3       B
#
#               Price
# 9069   88504.384965
# 2603  207007.956663
# 7738  182126.280899
# 1579  524365.550705
# 5058  322048.433990

# %% [markdown]
# ## Поле Price

# %%
train.groupby('DistrictId', as_index=False)[['Price']].mean().sort_values('Price', ascending=False)
# Out:
#      DistrictId          Price
# 189         190  516137.070651
# 198         202  502085.860162
# 194         195  482791.138606
# 180         181  477217.801361
# 181         182  471000.007453
# ..          ...            ...
# 58           58  155768.248590
# 192         193  155763.047489
# 201         209  140048.802277
# 102         102  138931.010464
# 23           23  126362.559842
#
# [202 rows x 2 columns]

# %%
#Установим параметр шума
noise_const = 15000

# %%
#Убедимся, что распределение шума близко к нормальному закону
noise = noise_const * np.random.randn(train.shape[0])

# %%
plt.hist(noise, bins=50)
# Out:
# (array([  1.,   0.,   0.,   1.,   1.,   1.,   2.,   6.,  10.,  11.,  19.,
#          22.,  21.,  43.,  84.,  82., 125., 129., 174., 252., 239., 272.,
#         359., 335., 396., 434., 404., 413., 415., 374., 387., 351., 332.,
#         259., 214., 206., 154., 119.,  95.,  65.,  65.,  39.,  33.,  17.,
#          16.,   8.,   4.,   5.,   2.,   4.]),
#  array([-61038.45316092, -58802.47836977, -56566.50357862, -54330.52878747,
#         -52094.55399632, -49858.57920517, -47622.60441402, -45386.62962287,
#         -43150.65483173, -40914.68004058, -38678.70524943, -36442.73045828,
#         -34206.75566713, -31970.78087598, -29734.80608483, -27498.83129368,
#         -25262.85650253, -23026.88171138, -20790.90692023, -18554.93212908,
#         -16318.95733794, -14082.98254679, -11847.00775564,  -9611.03296449,
#          -7375.05817334,  -5139.08338219,  -2903.10859104,   -667.13379989,
#           1568.84099126,   3804.81578241,   6040.79057356,   8276.7653647 ,
#          10512.74015585,  12748.714947  ,  14984.68973815,  17220.6645293 ,
#          19456.63932045,  21692.6141116 ,  23928.58890275,  26164.5636939 ,
#          28400.53848505,  30636.5132762 ,  32872.48806735,  35108.46285849,
#          37344.43764964,  39580.41244079,  41816.38723194,  44052.36202309,
#          46288.33681424,  48524.31160539,  50760.28639654]),
#  <BarContainer object of 50 artists>)

# %%
train.shape[0]
# Out:
# 7000

# %%
np.random.seed(42)

# %%
train['Price_n'] = train['Price'] + noise_const * np.random.randn(train.shape[0]) * (train['Rooms'] + 1)

# %%
train.loc[:, ['Price', 'Price_n']].head(10)
# Out:
#               Price        Price_n
# 9069   88504.384965  103405.809556
# 2603  207007.956663  198712.098592
# 7738  182126.280899  201556.937042
# 1579  524365.550705  615747.342090
# 5058  322048.433990  307999.231507
# 5753  282877.332154  268829.114737
# 3548  358129.914474  452882.683405
# 409   175973.694767  210508.257579
# 4097  240019.792399  218893.445032
# 6461  468039.075500  500592.678116

# %%
mean_price = train.groupby(['DistrictId', 'Rooms'], as_index=False)[['Price_n']].mean().\
    rename(columns={'Price_n':'mean_price'})
mean_price.head()
# Out:
#    DistrictId  Rooms     mean_price
# 0           0    1.0  125675.611519
# 1           0    2.0  180697.298932
# 2           0    3.0  268640.126763
# 3           1    1.0  147396.671134
# 4           1    2.0  195296.522967

# %%
mean_price2 = train.groupby('Rooms', as_index=False)[['Price_n']].mean().\
    rename(columns={'Price_n':'mean_price2'})
mean_price2
# Out:
#    Rooms    mean_price2
# 0    0.0  184897.022430
# 1    1.0  159777.943156
# 2    2.0  213862.735077
# 3    3.0  293565.372010
# 4    4.0  384741.955837
# 5    5.0  405924.621906
# 6    6.0   51901.498926
# 7   10.0  200460.018581
# 8   19.0  488426.896938

# %%
mean_price_all = train['Price_n'].mean()
mean_price_all
# Out:
# 214397.0825236982

# %%
#Создадим поле mean_price
def add_mean_price(df, mean_price=mean_price, mean_price2=mean_price2):
    global mean_price_all
    df = pd.merge(df, mean_price2, on='Rooms', how='left')
    df['mean_price2'] = df['mean_price2'].fillna(mean_price_all)
    df = pd.merge(df, mean_price, on=['DistrictId', 'Rooms'], how='left')
    df['mean_price'] = df['mean_price'].fillna(df['mean_price2'])
    df = df.drop('mean_price2', axis=1)
    return df

# %%
train = add_mean_price(train)

# %%
train.head()
# Out:
#       Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 0  14604          23    1.0   41.681380   22.796166            8.0     14
# 1   5621          23    3.0  163.495333  161.504222           12.0      5
# 2    235          87    1.0   39.710131   19.538663            8.0      4
# 3  16258          48    3.0   96.056784   98.152802            1.0     15
# 4  10773          77    3.0   79.195825   44.421062           10.0     16
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0        17.0     2015.0   0.075779         B         B         6      1437
# 1         3.0     1977.0   0.014073         B         B         2       475
# 2        17.0     1986.0   0.100456         B         B        43      7227
# 3         1.0     2017.0   0.041125         B         B        46      9515
# 4        17.0     1984.0   0.298205         B         B        16      4048
#
#    Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2          Price  \
# 0         3           NaN            0        2       B   88504.384965
# 1         0           NaN            0        0       B  207007.956663
# 2         0           NaN            1        6       A  182126.280899
# 3         5           NaN            1       10       B  524365.550705
# 4         3           NaN            1        3       B  322048.433990
#
#          Price_n     mean_price
# 0  103405.809556  101527.520988
# 1  198712.098592  183792.412835
# 2  201556.937042  176782.540583
# 3  615747.342090  392708.354017
# 4  307999.231507  267043.942055

# %% [markdown]
# ## Преобразуем некоторые поля в категориальные

# %%
train['Ecology_2'].unique()
# Out:
# array(['B', 'A'], dtype=object)

# %%
train['Ecology_3'].unique()
# Out:
# array(['B', 'A'], dtype=object)

# %%
train['Shops_2'].unique()
# Out:
# array(['B', 'A'], dtype=object)

# %%
def convert_to_category(df):
    df['Ecology_2'] = df['Ecology_2'].astype('category')
    df['Ecology_3'] = df['Ecology_3'].astype('category')
    df['Shops_2'] = df['Shops_2'].astype('category')
    df = pd.get_dummies(df)
    return df

# %%
train = convert_to_category(train)
train.head(10)
# Out:
#       Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 0  14604          23    1.0   41.681380   22.796166            8.0     14
# 1   5621          23    3.0  163.495333  161.504222           12.0      5
# 2    235          87    1.0   39.710131   19.538663            8.0      4
# 3  16258          48    3.0   96.056784   98.152802            1.0     15
# 4  10773          77    3.0   79.195825   44.421062           10.0     16
# 5   3766          62    3.0  127.417560         NaN            0.0      9
# 6  11463         129    3.0   72.953912   39.478723            9.0     16
# 7  15037          11    2.0   46.430852   31.678912            5.0      2
# 8   4389          39    2.0   54.326263   34.394391            9.0      3
# 9  15829         104    3.0   75.777599   45.381156            9.0      2
#
#    HouseFloor  HouseYear  Ecology_1  Social_1  Social_2  Social_3  \
# 0        17.0     2015.0   0.075779         6      1437         3
# 1         3.0     1977.0   0.014073         2       475         0
# 2        17.0     1986.0   0.100456        43      7227         0
# 3         1.0     2017.0   0.041125        46      9515         5
# 4        17.0     1984.0   0.298205        16      4048         3
# 5         0.0     1977.0   0.072158         2       629         1
# 6        15.0     1991.0   0.460556        20      4386        14
# 7         5.0     1960.0   0.038693        28      6533         1
# 8        12.0     1974.0   0.428826        25      5011         8
# 9         9.0     1985.0   0.327018        12      2270        23
#
#    Healthcare_1  Helthcare_2  Shops_1          Price        Price_n  \
# 0           NaN            0        2   88504.384965  103405.809556
# 1           NaN            0        0  207007.956663  198712.098592
# 2           NaN            1        6  182126.280899  201556.937042
# 3           NaN            1       10  524365.550705  615747.342090
# 4           NaN            1        3  322048.433990  307999.231507
# 5           NaN            0        0  282877.332154  268829.114737
# 6           NaN            1        5  358129.914474  452882.683405
# 7        1015.0            2        5  175973.694767  210508.257579
# 8         730.0            0        2  240019.792399  218893.445032
# 9        2500.0            1        0  468039.075500  500592.678116
#
#       mean_price  Ecology_2_A  Ecology_2_B  Ecology_3_A  Ecology_3_B  \
# 0  101527.520988            0            1            0            1
# 1  183792.412835            0            1            0            1
# 2  176782.540583            0            1            0            1
# 3  392708.354017            0            1            0            1
# 4  267043.942055            0            1            0            1
# 5  247163.255296            0            1            0            1
# 6  324706.712048            0            1            0            1
# 7  208449.140884            0            1            0            1
# 8  175938.251765            0            1            0            1
# 9  411923.711092            0            1            0            1
#
#    Shops_2_A  Shops_2_B
# 0          0          1
# 1          0          1
# 2          1          0
# 3          0          1
# 4          0          1
# 5          1          0
# 6          0          1
# 7          0          1
# 8          0          1
# 9          0          1

# %% [markdown]
# # Model

# %%
#Построим модель. Воспользуемся RandomForestRegressor
#Подключим библиотеки
from sklearn.ensemble import RandomForestRegressor as RFR
from sklearn.metrics import r2_score as r2

# %%
#Обработаем валидационный датасет
valid = clean_year(valid)
valid = add_mean_price(valid)
valid = convert_to_category(valid)

# %%
#Создадим список признаков
feats = ['Shops_1', 'Ecology_2_A', 'Rooms', 'Square', 'HouseYear', 'KitchenSquare', 'HouseFloor', 'Ecology_1', 'Social_3', 'mean_price']

# %%
#Оценим модель с заданными параметрами
def evaluate_model(model, train, valid, metric, feats, target, max_depth):
    dtr = model(max_depth=max_depth, n_estimators=100, random_state=42)
    dtr.fit(train.loc[:, feats], train[target])
    y_pred_train = dtr.predict(train.loc[:, feats])
    y_pred_valid = dtr.predict(valid.loc[:, feats])
    metric_train = metric(train[target], y_pred_train)
    metric_valid = metric(valid[target], y_pred_valid)
    return metric_train, metric_valid

# %%
#Зафиксируем результаты обучения
def check_param(min_value, max_value, model, train=train, valid=valid, metric=r2, feats=feats, 
                             target='Price'):
    max_depth_arr = []
    metric_train_arr = []
    metric_valid_arr = []

    for i in range(min_value, max_value+1):
        res = evaluate_model(model, train, valid, metric, feats, 
                             target, max_depth=i)
        max_depth_arr.append(i)
        metric_train_arr.append(res[0])
        metric_valid_arr.append(res[1])
    return max_depth_arr, metric_train_arr, metric_valid_arr

# %%
max_depth_arr, metric_train_arr, metric_valid_arr = check_param(min_value=1, max_value=20, model=RFR)

# %%
#Визуализируем процесс обучения на графике
plt.plot(max_depth_arr, metric_train_arr)
plt.plot(max_depth_arr, metric_valid_arr)

# %%
np.max(metric_valid_arr)
# Out:
# 0.7020433565475931

# %%
metric_valid_arr
# Out:
# [0.3698266599357789,
#  0.526530129584556,
#  0.5722863927270414,
#  0.6034510689091095,
#  0.6299096454985402,
#  0.6499042287001551,
#  0.6667769172333073,
#  0.680039931115116,
#  0.6887186757686516,
#  0.6941794645215258,
#  0.6978727798534631,
#  0.6995799450312251,
#  0.6996801729585453,
#  0.7007695737492369,
#  0.7004943588107972,
#  0.7006236703803372,
#  0.7020433565475931,
#  0.7003636800123378,
#  0.70031847594403,
#  0.7004538308147812]

# %%
#Установим модели оптимальные параметры
model = RFR(max_depth=17, random_state=42)

# %%
#Обучим модель
model.fit(train.loc[:, feats], train['Price'])
# Out:
# RandomForestRegressor(max_depth=17, random_state=42)

# %% [markdown]
# # Test

# %%
#Считаем тестовый датасет
test = pd.read_csv('input.test.csv')

# %%
#Обработаем тестовый датасет
test = clean_year(test)
test = add_mean_price(test)
test = convert_to_category(test)

# %%
#Рассчитаем Price для тестового датасета
test['Price'] = model.predict(test.loc[:, feats])

# %%
#Сохраним результат в файл
test.loc[:, ['Id', 'Price']].to_csv('AIbragimov2_predictions.csv', index=None)
